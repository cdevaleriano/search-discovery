# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cdevaleriano/search-discovery/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Refresh / Content Opportunity Scoring  -  I have not experienced building recommendation algorithms, and I want to explore outside of my comfort zone. Thus, I chose this track.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# My work improves on determining which pages should be focused on to which the decisions help content writers. A wrong recommendation costs wasted time and effort in improving pages whose content does not need to be improved.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")


import pandas as pd, numpy as np
df = pd.read_csv("../data/raw/content_refresh_anonymized.csv")
df["is_declining_label"] = df["trend_direction"].str.lower().eq("down").astype(int)

from sklearn.tree import DecisionTreeClassifier

def precision_at_k(scores, labels, k):
    order = np.argsort(-np.asarray(scores))
    topk = np.asarray(labels)[order[:k]]
    return topk.mean()

features = ["content_age_days", "days_since_last_update", "impressions_90d",
            "avg_position", "ctr", "word_count"]
X = df[features].replace([np.inf, -np.inf], np.nan).fillna(0)
y = df["is_declining_label"].values

tree = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42)
tree.fit(X, y)

features2= ["content_age_days", "days_since_last_update", "engagement_rate",
            "avg_position", "ctr", "word_count"]
X2 = df[features2].replace([np.inf, -np.inf], np.nan).fillna(0)
tree2 = DecisionTreeClassifier(max_depth=4, class_weight="balanced", random_state=42)
tree2.fit(X2, y)

tree_score = tree.predict_proba(X)[:, 1]
tree_score2 = tree2.predict_proba(X2)[:, 1]
for k in (20, 50):
    tr1 = precision_at_k(tree_score, y, k)
    tr2 = precision_at_k(tree_score2, y, k)
    print(f"Precision@{k}:  depth 2 {tr1:.3f}   vs   depth4 {tr2:.3f}")
# Out:
# Precision@20:  depth 2 0.800   vs   depth4 0.700
# Precision@50:  depth 2 0.720   vs   depth4 0.740

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# My work will be able to observe pages with content opportunities but it will never provide causal inferences nor serve as a model that predicts Google results.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [/] Every section above is filled — markdown thinking AND the code that backs it
# - [/] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [/] No client names, URLs, or private queries anywhere
# - [/] My claims use careful words: observed, measured, directional, decision-support
# - [/] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
